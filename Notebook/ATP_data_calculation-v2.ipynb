# %%
#Import data set
import pandas as pd
df = pd.read_csv("atp_matches_till_2022.csv", sep=',')
df.tail()
# Out:
#                               tourney_id                  tourney_name  \
# 188156  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM
# 188157  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM
# 188158  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN
# 188159  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN
# 188160  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN
#
#        surface  draw_size tourney_level  tourney_date  match_num  winner_id  \
# 188156    Clay          4             D      20220304          4     209362
# 188157    Clay          4             D      20220304          5     202065
# 188158    Hard          4             D      20220304          1     138846
# 188159    Hard          4             D      20220304          2     209409
# 188160    Hard          4             D      20220304          4     208414
#
#         winner_seed winner_entry         winner_name winner_hand  winner_ht  \
# 188156          NaN          NaN  Aristotelis Thanos           R        NaN
# 188157          NaN          NaN    Petros Tsitsipas           U      185.0
# 188158          NaN          NaN  Hong Kit Jack Wong           R        NaN
# 188159          NaN          NaN        Coleman Wong           R        NaN
# 188160          NaN          NaN    Sylvestre Monnou           R        NaN
#
#        winner_ioc  winner_age  loser_id  loser_seed loser_entry  \
# 188156        GRE        20.8    209080         NaN         NaN
# 188157        GRE        21.5    202120         NaN         NaN
# 188158        HKG        23.4    105278         NaN         NaN
# 188159        HKG        17.7    200583         NaN         NaN
# 188160        BEN        19.2    207132         NaN         NaN
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# 188156   Blaise Bicknell          R     188.0       USA       20.2
# 188157  Rowland Phillips          R       NaN       JAM       28.0
# 188158     Alexis Klegou          U       NaN       BEN       33.0
# 188159      Delmas Ntcha          R       NaN       BEN       21.7
# 188160        Ki Lung Ng          R       NaN       HKG        NaN
#
#                   score  best_of round  minutes  w_ace  w_df  w_svpt  w_1stIn  \
# 188156          6-4 6-4        3    RR    115.0    0.0   4.0    70.0     48.0
# 188157      4-6 6-4 6-4        3    RR    161.0    7.0   2.0    94.0     55.0
# 188158  1-6 6-4 4-1 RET        3    RR    250.0    4.0   8.0    56.0     33.0
# 188159          6-4 6-4        3    RR     98.0    2.0   2.0    68.0     38.0
# 188160          6-4 6-4        3    RR     92.0    5.0   5.0    70.0     32.0
#
#         w_1stWon  w_2ndWon  w_SvGms  w_bpSaved  w_bpFaced  l_ace  l_df  \
# 188156      35.0      12.0     10.0        5.0        5.0    1.0   3.0
# 188157      37.0      23.0     15.0        9.0       12.0    1.0   1.0
# 188158      20.0      13.0     11.0        3.0        7.0    0.0   3.0
# 188159      24.0      18.0     10.0        6.0        8.0    1.0   5.0
# 188160      28.0      17.0     10.0        4.0        5.0    6.0   2.0
#
#         l_svpt  l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced  \
# 188156    96.0     68.0      42.0      12.0     10.0       11.0       13.0
# 188157    94.0     56.0      40.0      20.0     15.0        4.0        8.0
# 188158    72.0     54.0      29.0       8.0     11.0        6.0       10.0
# 188159    58.0     39.0      24.0       7.0     10.0        5.0        9.0
# 188160    60.0     34.0      24.0      13.0     10.0        5.0        8.0
#
#         winner_rank  winner_rank_points  loser_rank  loser_rank_points
# 188156       1103.0                 9.0      1130.0                8.0
# 188157        808.0                23.0      1390.0                4.0
# 188158       1059.0                10.0      1881.0                1.0
# 188159          NaN                 NaN         NaN                NaN
# 188160          NaN                 NaN         NaN                NaN

# %%
#Show all columns
pd.set_option('display.max_columns', None)
df.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
#Rename columns
df.rename(columns={
    'tourney_id': 'Tournament_ID',
    'tourney_name': 'Tournament_Name',
    'surface': 'Surface',
    'draw_size': 'Draw_Size',
    'tourney_level': 'Tournament_Level',
    'tourney_date': 'Tournament_Date',
    'match_num': 'Match_Number',
    'winner_id': 'Winner_ID',
    'winner_seed': 'Winner_Seed',
    'winner_entry': 'Winner_Entry',
    'winner_name': 'Winner_Name',
    'winner_hand': 'Winner_Hand',
    'winner_ht': 'Winner_Height',
    'winner_ioc': 'Winner_Country',
    'winner_age': 'Winner_Age',
    'loser_id': 'Loser_ID',
    'loser_seed': 'Loser_Seed',
    'loser_entry': 'Loser_Entry',
    'loser_name': 'Loser_Name',
    'loser_hand': 'Loser_Hand',
    'loser_ht': 'Loser_Height',
    'loser_ioc': 'Loser_Country',
    'loser_age': 'Loser_Age',
    'score': 'Match_Score',
    'best_of': 'Best_Of_Sets',
    'round': 'Round',
    'minutes': 'Match_Duration_Minutes',
    'w_ace': 'Winner_Aces',
    'w_df': 'Winner_DoubleFaults',
    'w_svpt': 'Winner_ServePoints',
    'w_1stIn': 'Winner_FirstServeIn',
    'w_1stWon': 'Winner_FirstServeWon',
    'w_2ndWon': 'Winner_SecondServeWon',
    'w_SvGms': 'Winner_ServiceGames',
    'w_bpSaved': 'Winner_BreakPointsSaved',
    'w_bpFaced': 'Winner_BreakPointsFaced',
    'l_ace': 'Loser_Aces',
    'l_df': 'Loser_DoubleFaults',
    'l_svpt': 'Loser_ServePoints',
    'l_1stIn': 'Loser_FirstServeIn',
    'l_1stWon': 'Loser_FirstServeWon',
    'l_2ndWon': 'Loser_SecondServeWon',
    'l_SvGms': 'Loser_ServiceGames',
    'l_bpSaved': 'Loser_BreakPointsSaved',
    'l_bpFaced': 'Loser_BreakPointsFaced',
    'winner_rank': 'Winner_Rank',
    'winner_rank_points': 'Winner_Rank_Points',
    'loser_rank': 'Loser_Rank',
    'loser_rank_points': 'Loser_Rank_Points'
}, inplace=True)

# %%
df.columns.tolist()
# Out:
# ['Tournament_ID',
#  'Tournament_Name',
#  'Surface',
#  'Draw_Size',
#  'Tournament_Level',
#  'Tournament_Date',
#  'Match_Number',
#  'Winner_ID',
#  'Winner_Seed',
#  'Winner_Entry',
#  'Winner_Name',
#  'Winner_Hand',
#  'Winner_Height',
#  'Winner_Country',
#  'Winner_Age',
#  'Loser_ID',
#  'Loser_Seed',
#  'Loser_Entry',
#  'Loser_Name',
#  'Loser_Hand',
#  'Loser_Height',
#  'Loser_Country',
#  'Loser_Age',
#  'Match_Score',
#  'Best_Of_Sets',
#  'Round',
#  'Match_Duration_Minutes',
#  'Winner_Aces',
#  'Winner_DoubleFaults',
#  'Winner_ServePoints',
#  'Winner_FirstServeIn',
#  'Winner_FirstServeWon',
#  'Winner_SecondServeWon',
#  'Winner_ServiceGames',
#  'Winner_BreakPointsSaved',
#  'Winner_BreakPointsFaced',
#  'Loser_Aces',
#  'Loser_DoubleFaults',
#  'Loser_ServePoints',
#  'Loser_FirstServeIn',
#  'Loser_FirstServeWon',
#  'Loser_SecondServeWon',
#  'Loser_ServiceGames',
#  'Loser_BreakPointsSaved',
#  'Loser_BreakPointsFaced',
#  'Winner_Rank',
#  'Winner_Rank_Points',
#  'Loser_Rank',
#  'Loser_Rank_Points']

# %%
#Display all columns
pd.set_option('display.max_rows', None)
df.tail(15)
# Out:
#                            Tournament_ID               Tournament_Name  \
# 188146   2022-M-DC-2022-WG2-M-URU-CHN-01  Davis Cup WG2 R1: URU vs CHN
# 188147   2022-M-DC-2022-WG2-M-URU-CHN-01  Davis Cup WG2 R1: URU vs CHN
# 188148   2022-M-DC-2022-WG2-M-URU-CHN-01  Davis Cup WG2 R1: URU vs CHN
# 188149   2022-M-DC-2022-WG2-M-URU-CHN-01  Davis Cup WG2 R1: URU vs CHN
# 188150  2022-M-DC-2022-WG2-PO-EGY-CYP-01  Davis Cup WG2 PO: EGY vs CYP
# 188151  2022-M-DC-2022-WG2-PO-EGY-CYP-01  Davis Cup WG2 PO: EGY vs CYP
# 188152  2022-M-DC-2022-WG2-PO-EGY-CYP-01  Davis Cup WG2 PO: EGY vs CYP
# 188153  2022-M-DC-2022-WG2-PO-EGY-CYP-01  Davis Cup WG2 PO: EGY vs CYP
# 188154  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM
# 188155  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM
# 188156  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM
# 188157  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM
# 188158  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN
# 188159  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN
# 188160  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN
#
#        Surface  Draw_Size Tournament_Level  Tournament_Date  Match_Number  \
# 188146    Clay          4                D         20220916             1
# 188147    Clay          4                D         20220916             2
# 188148    Clay          4                D         20220916             4
# 188149    Clay          4                D         20220916             5
# 188150    Clay          4                D         20220304             1
# 188151    Clay          4                D         20220304             2
# 188152    Clay          4                D         20220304             4
# 188153    Clay          4                D         20220304             5
# 188154    Clay          4                D         20220304             1
# 188155    Clay          4                D         20220304             2
# 188156    Clay          4                D         20220304             4
# 188157    Clay          4                D         20220304             5
# 188158    Hard          4                D         20220304             1
# 188159    Hard          4                D         20220304             2
# 188160    Hard          4                D         20220304             4
#
#         Winner_ID  Winner_Seed Winner_Entry                      Winner_Name  \
# 188146     111190          NaN          NaN                    Zhizhen Zhang
# 188147     105899          NaN          NaN                    Martin Cuevas
# 188148     111190          NaN          NaN                    Zhizhen Zhang
# 188149     144751          NaN          NaN                        Rigele Te
# 188150     105633          NaN          NaN                   Mohamed Safwat
# 188151     117365          NaN          NaN                Petros Chrysochos
# 188152     105633          NaN          NaN                   Mohamed Safwat
# 188153     209871          NaN          NaN  Amr Elsayed Abdou Ahmed Mohamed
# 188154     202120          NaN          NaN                 Rowland Phillips
# 188155     209080          NaN          NaN                  Blaise Bicknell
# 188156     209362          NaN          NaN               Aristotelis Thanos
# 188157     202065          NaN          NaN                 Petros Tsitsipas
# 188158     138846          NaN          NaN               Hong Kit Jack Wong
# 188159     209409          NaN          NaN                     Coleman Wong
# 188160     208414          NaN          NaN                 Sylvestre Monnou
#
#        Winner_Hand  Winner_Height Winner_Country  Winner_Age  Loser_ID  \
# 188146           R          193.0            CHN        25.9    202378
# 188147           R          188.0            URU        30.6    207352
# 188148           R          193.0            CHN        25.9    105899
# 188149           U            NaN            CHN        24.9    202378
# 188150           R          183.0            EGY        31.4    144949
# 188151           R          185.0            CYP        25.8    105747
# 188152           R          183.0            EGY        31.4    117365
# 188153           U            NaN            EGY        22.9    210308
# 188154           R            NaN            JAM        28.0    133018
# 188155           R          188.0            USA        20.2    202065
# 188156           R            NaN            GRE        20.8    209080
# 188157           U          185.0            GRE        21.5    202120
# 188158           R            NaN            HKG        23.4    105278
# 188159           R            NaN            HKG        17.7    200583
# 188160           R            NaN            BEN        19.2    207132
#
#         Loser_Seed Loser_Entry               Loser_Name Loser_Hand  \
# 188146         NaN         NaN            Ignacio Carou          U
# 188147         NaN         NaN           Bu Yunchaokete          U
# 188148         NaN         NaN            Martin Cuevas          R
# 188149         NaN         NaN            Ignacio Carou          U
# 188150         NaN         NaN      Menelaos Efstathiou          R
# 188151         NaN         NaN    Karim Mohamed Maamoun          R
# 188152         NaN         NaN        Petros Chrysochos          R
# 188153         NaN         NaN  Stylianos Christodoulou          U
# 188154         NaN         NaN     Michail Pervolarakis          R
# 188155         NaN         NaN         Petros Tsitsipas          U
# 188156         NaN         NaN          Blaise Bicknell          R
# 188157         NaN         NaN         Rowland Phillips          R
# 188158         NaN         NaN            Alexis Klegou          U
# 188159         NaN         NaN             Delmas Ntcha          R
# 188160         NaN         NaN               Ki Lung Ng          R
#
#         Loser_Height Loser_Country  Loser_Age      Match_Score  Best_Of_Sets  \
# 188146         178.0           ARG       23.1          6-2 6-2             3
# 188147           NaN           CHN       20.6   4-6 6-4 7-6(4)             3
# 188148         188.0           URU       30.6          6-0 6-2             3
# 188149         178.0           ARG       23.1       6-3 7-6(3)             3
# 188150           NaN           CYP       22.9          6-3 6-2             3
# 188151         175.0           EGY       30.8          6-3 6-4             3
# 188152         185.0           CYP       25.8      5-7 6-2 6-0             3
# 188153           NaN           CYP       17.3          6-3 6-3             3
# 188154         193.0           CYP       25.7      6-2 4-6 6-3             3
# 188155         185.0           GRE       21.5          6-3 7-5             3
# 188156         188.0           USA       20.2          6-4 6-4             3
# 188157           NaN           JAM       28.0      4-6 6-4 6-4             3
# 188158           NaN           BEN       33.0  1-6 6-4 4-1 RET             3
# 188159           NaN           BEN       21.7          6-4 6-4             3
# 188160           NaN           HKG        NaN          6-4 6-4             3
#
#        Round  Match_Duration_Minutes  Winner_Aces  Winner_DoubleFaults  \
# 188146    RR                     NaN          NaN                  NaN
# 188147    RR                     NaN          NaN                  NaN
# 188148    RR                     NaN          NaN                  NaN
# 188149    RR                     NaN          NaN                  NaN
# 188150    RR                    69.0          4.0                  2.0
# 188151    RR                    85.0          2.0                  0.0
# 188152    RR                   119.0          3.0                  3.0
# 188153    RR                    63.0          3.0                  3.0
# 188154    RR                   130.0          3.0                  3.0
# 188155    RR                    95.0          1.0                  4.0
# 188156    RR                   115.0          0.0                  4.0
# 188157    RR                   161.0          7.0                  2.0
# 188158    RR                   250.0          4.0                  8.0
# 188159    RR                    98.0          2.0                  2.0
# 188160    RR                    92.0          5.0                  5.0
#
#         Winner_ServePoints  Winner_FirstServeIn  Winner_FirstServeWon  \
# 188146                 NaN                  NaN                   NaN
# 188147                 NaN                  NaN                   NaN
# 188148                 NaN                  NaN                   NaN
# 188149                 NaN                  NaN                   NaN
# 188150                50.0                 30.0                  26.0
# 188151                69.0                 43.0                  32.0
# 188152                74.0                 43.0                  31.0
# 188153                63.0                 38.0                  29.0
# 188154                84.0                 49.0                  36.0
# 188155                63.0                 38.0                  31.0
# 188156                70.0                 48.0                  35.0
# 188157                94.0                 55.0                  37.0
# 188158                56.0                 33.0                  20.0
# 188159                68.0                 38.0                  24.0
# 188160                70.0                 32.0                  28.0
#
#         Winner_SecondServeWon  Winner_ServiceGames  Winner_BreakPointsSaved  \
# 188146                    NaN                  NaN                      NaN
# 188147                    NaN                  NaN                      NaN
# 188148                    NaN                  NaN                      NaN
# 188149                    NaN                  NaN                      NaN
# 188150                   11.0                  9.0                      1.0
# 188151                   13.0                 10.0                      5.0
# 188152                   17.0                 13.0                      2.0
# 188153                   14.0                  9.0                      5.0
# 188154                   19.0                 14.0                      3.0
# 188155                   11.0                 11.0                      3.0
# 188156                   12.0                 10.0                      5.0
# 188157                   23.0                 15.0                      9.0
# 188158                   13.0                 11.0                      3.0
# 188159                   18.0                 10.0                      6.0
# 188160                   17.0                 10.0                      4.0
#
#         Winner_BreakPointsFaced  Loser_Aces  Loser_DoubleFaults  \
# 188146                      NaN         NaN                 NaN
# 188147                      NaN         NaN                 NaN
# 188148                      NaN         NaN                 NaN
# 188149                      NaN         NaN                 NaN
# 188150                      1.0         0.0                 3.0
# 188151                      7.0         0.0                 1.0
# 188152                      5.0         2.0                 1.0
# 188153                      5.0         3.0                 1.0
# 188154                      5.0         2.0                 2.0
# 188155                      5.0         0.0                 2.0
# 188156                      5.0         1.0                 3.0
# 188157                     12.0         1.0                 1.0
# 188158                      7.0         0.0                 3.0
# 188159                      8.0         1.0                 5.0
# 188160                      5.0         6.0                 2.0
#
#         Loser_ServePoints  Loser_FirstServeIn  Loser_FirstServeWon  \
# 188146                NaN                 NaN                  NaN
# 188147                NaN                 NaN                  NaN
# 188148                NaN                 NaN                  NaN
# 188149                NaN                 NaN                  NaN
# 188150               41.0                28.0                 15.0
# 188151               57.0                38.0                 21.0
# 188152               90.0                56.0                 26.0
# 188153               54.0                27.0                 17.0
# 188154               77.0                41.0                 22.0
# 188155               64.0                38.0                 23.0
# 188156               96.0                68.0                 42.0
# 188157               94.0                56.0                 40.0
# 188158               72.0                54.0                 29.0
# 188159               58.0                39.0                 24.0
# 188160               60.0                34.0                 24.0
#
#         Loser_SecondServeWon  Loser_ServiceGames  Loser_BreakPointsSaved  \
# 188146                   NaN                 NaN                     NaN
# 188147                   NaN                 NaN                     NaN
# 188148                   NaN                 NaN                     NaN
# 188149                   NaN                 NaN                     NaN
# 188150                   7.0                 8.0                     0.0
# 188151                  10.0                 9.0                     4.0
# 188152                  17.0                13.0                     8.0
# 188153                  16.0                 9.0                     6.0
# 188154                  20.0                13.0                     4.0
# 188155                  14.0                10.0                     0.0
# 188156                  12.0                10.0                    11.0
# 188157                  20.0                15.0                     4.0
# 188158                   8.0                11.0                     6.0
# 188159                   7.0                10.0                     5.0
# 188160                  13.0                10.0                     5.0
#
#         Loser_BreakPointsFaced  Winner_Rank  Winner_Rank_Points  Loser_Rank  \
# 188146                     NaN        122.0               436.0       617.0
# 188147                     NaN        404.0               105.0       340.0
# 188148                     NaN        122.0               436.0       404.0
# 188149                     NaN        537.0                54.0       617.0
# 188150                     3.0        355.0               120.0      1041.0
# 188151                     8.0        486.0                69.0       626.0
# 188152                    15.0        355.0               120.0       486.0
# 188153                     9.0       1237.0                 6.0      1445.0
# 188154                     8.0       1390.0                 4.0       402.0
# 188155                     4.0       1130.0                 8.0       808.0
# 188156                    13.0       1103.0                 9.0      1130.0
# 188157                     8.0        808.0                23.0      1390.0
# 188158                    10.0       1059.0                10.0      1881.0
# 188159                     9.0          NaN                 NaN         NaN
# 188160                     8.0          NaN                 NaN         NaN
#
#         Loser_Rank_Points
# 188146               42.0
# 188147              135.0
# 188148              105.0
# 188149               42.0
# 188150               10.0
# 188151               43.0
# 188152               69.0
# 188153                3.0
# 188154               98.0
# 188155               23.0
# 188156                8.0
# 188157                4.0
# 188158                1.0
# 188159                NaN
# 188160                NaN

# %%
#Set columns that will be used for calculation to df_clean
columns_for_calculation = [
    'Winner_Age', 'Winner_Height', 'Winner_Seed', 'Winner_Rank',
    'Winner_Aces', 'Winner_DoubleFaults', 'Match_Duration_Minutes',
    'Loser_Age', 'Loser_Height', 'Loser_Seed', 'Loser_Rank',
    'Loser_Aces', 'Loser_DoubleFaults'
]

df_clean = df.dropna(subset=columns_for_calculation)

df_clean[columns_for_calculation].isnull().sum()

print("Dataset for calcution, removed null value rows:", df_clean.shape)

df_clean.head()
# Out:
# Dataset for calcution, removed null value rows: (8264, 49)
#       Tournament_ID  Tournament_Name Surface  Draw_Size Tournament_Level  \
# 85877      1991-339         Adelaide    Hard         32                A
# 86084      1991-580  Australian Open    Hard        128                G
# 86086      1991-580  Australian Open    Hard        128                G
# 86095      1991-580  Australian Open    Hard        128                G
# 86096      1991-580  Australian Open    Hard        128                G
#
#        Tournament_Date  Match_Number  Winner_ID  Winner_Seed Winner_Entry  \
# 85877         19901231            30     101529          6.0          NaN
# 86084         19910114           113     101222          1.0          NaN
# 86086         19910114           115     100656          3.0          NaN
# 86095         19910114           124     101414          2.0          NaN
# 86096         19910114           125     100656          3.0          NaN
#
#          Winner_Name Winner_Hand  Winner_Height Winner_Country  Winner_Age  \
# 85877  Michael Stich           R          193.0            GER        22.2
# 86084  Stefan Edberg           R          188.0            SWE        24.9
# 86086     Ivan Lendl           R          188.0            USA        30.8
# 86095   Boris Becker           R          190.0            GER        23.1
# 86096     Ivan Lendl           R          188.0            USA        30.8
#
#        Loser_ID  Loser_Seed Loser_Entry        Loser_Name Loser_Hand  \
# 85877    101793         2.0         NaN       Jim Courier          R
# 86084    101793        16.0         NaN       Jim Courier          R
# 86086    101381        13.0         NaN  Aaron Krickstein          R
# 86095    101098        10.0         NaN        Guy Forget          L
# 86096    101222         1.0         NaN     Stefan Edberg          R
#
#        Loser_Height Loser_Country  Loser_Age             Match_Score  \
# 85877         185.0           USA       20.3              6-4 7-6(6)
# 86084         185.0           USA       20.4     4-6 6-0 6-4 5-7 6-2
# 86086         183.0           USA       23.4             6-2 6-2 6-1
# 86095         190.0           FRA       26.0             6-2 7-6 6-3
# 86096         188.0           SWE       24.9  6-4 5-7 3-6 7-6(3) 6-4
#
#        Best_Of_Sets Round  Match_Duration_Minutes  Winner_Aces  \
# 85877             3    SF                   104.0          7.0
# 86084             5   R16                   210.0          9.0
# 86086             5   R16                   110.0         11.0
# 86095             5    QF                   111.0         14.0
# 86096             5    SF                   242.0         12.0
#
#        Winner_DoubleFaults  Winner_ServePoints  Winner_FirstServeIn  \
# 85877                  4.0                80.0                 37.0
# 86084                  7.0               169.0                119.0
# 86086                  6.0                70.0                 34.0
# 86095                  3.0                81.0                 50.0
# 86096                  4.0               165.0                 95.0
#
#        Winner_FirstServeWon  Winner_SecondServeWon  Winner_ServiceGames  \
# 85877                  26.0                   27.0                 11.0
# 86084                  87.0                   22.0                 23.0
# 86086                  30.0                   19.0                 11.0
# 86095                  43.0                   24.0                 15.0
# 86096                  70.0                   34.0                 26.0
#
#        Winner_BreakPointsSaved  Winner_BreakPointsFaced  Loser_Aces  \
# 85877                      5.0                      6.0         2.0
# 86084                     14.0                     16.0         8.0
# 86086                      1.0                      1.0         3.0
# 86095                      0.0                      0.0         6.0
# 86096                      6.0                     12.0         6.0
#
#        Loser_DoubleFaults  Loser_ServePoints  Loser_FirstServeIn  \
# 85877                 2.0               71.0                40.0
# 86084                 3.0              151.0               101.0
# 86086                 2.0               89.0                53.0
# 86095                 1.0               80.0                39.0
# 86096                10.0              161.0                97.0
#
#        Loser_FirstServeWon  Loser_SecondServeWon  Loser_ServiceGames  \
# 85877                 29.0                  18.0                11.0
# 86084                 63.0                  26.0                23.0
# 86086                 28.0                  12.0                12.0
# 86095                 28.0                  25.0                14.0
# 86096                 68.0                  35.0                27.0
#
#        Loser_BreakPointsSaved  Loser_BreakPointsFaced  Winner_Rank  \
# 85877                     1.0                     3.0         42.0
# 86084                     7.0                    13.0          1.0
# 86086                     7.0                    14.0          3.0
# 86095                     2.0                     5.0          2.0
# 86096                     4.0                    10.0          3.0
#
#        Winner_Rank_Points  Loser_Rank  Loser_Rank_Points
# 85877                 NaN        25.0                NaN
# 86084              3889.0        23.0              950.0
# 86086              2541.0        22.0              967.0
# 86095              3528.0        13.0             1229.0
# 86096              2541.0         1.0             3889.0

# %%
df_clean.shape[0]
# Out:
# 8264

# %%
#Get central tendency
print("Winner Age - Mean:", df['Winner_Age'].mean())
print('Winner Age - Mediam:', df['Winner_Age'].median())
print('Winner Age - Mode:', df['Winner_Age'].mode())
# Out:
# Winner Age - Mean: 25.658361791185378
# Winner Age - Mediam: 25.2
# Winner Age - Mode: 0    24.0
# Name: Winner_Age, dtype: float64

# %%
#Get central tendency

#Age
print("Winner Age - Mean:", df_clean['Winner_Age'].mean())
print("Winner Age - Median:", df_clean['Winner_Age'].median())
print("Winner Age - Mode:", df_clean['Winner_Age'].mode().values[0])

print("Loser Age - Mean:", df_clean['Loser_Age'].mean())
print("Loser Age - Median:", df_clean['Loser_Age'].median())
print("Loser Age - Mode:", df_clean['Loser_Age'].mode().values[0])

print("\n")

#Height
print("Winner Height - Mean:", df_clean['Winner_Height'].mean())
print("Winner Height - Median:", df_clean['Winner_Height'].median())
print("Winner Height - Mode:", df_clean['Winner_Height'].mode().values[0])

print("Loser Height - Mean:", df_clean['Loser_Height'].mean())
print("Loser Height - Median:", df_clean['Loser_Height'].median())
print("Loser Height - Mode:", df_clean['Loser_Height'].mode().values[0])

print("\n")

#Rank
print("Winner Rank - Mean:", df_clean['Winner_Rank'].mean())
print("Winner Rank - Median:", df_clean['Winner_Rank'].median())
print("Winner Rank - Mode:", df_clean['Winner_Rank'].mode().values[0])

print("Loser Rank - Mean:", df_clean['Loser_Rank'].mean())
print("Loser Rank - Median:", df_clean['Loser_Rank'].median())
print("Loser Rank - Mode:", df_clean['Loser_Rank'].mode().values[0])
# Out:
# Winner Age - Mean: 25.85073814133591
# Winner Age - Median: 25.5
# Winner Age - Mode: 23.6
# Loser Age - Mean: 26.067013552758954
# Loser Age - Median: 25.8
# Loser Age - Mode: 25.9
#
#
# Winner Height - Mean: 186.60926911907066
# Winner Height - Median: 185.0
# Winner Height - Mode: 185.0
# Loser Height - Mean: 186.40004840271055
# Loser Height - Median: 185.0
# Loser Height - Mode: 185.0
#
#
# Winner Rank - Mean: 16.737052274927397
# Winner Rank - Median: 11.0
# Winner Rank - Mode: 1.0
# Loser Rank - Mean: 23.212003872216844
# Loser Rank - Median: 18.0
# Loser Rank - Mode: 7.0

# %%
#variance and standard deviation

columns = ['Winner_Age', 'Loser_Age', 'Winner_Height', 'Loser_Height', 'Winner_Rank', 'Loser_Rank']

for col in columns:
    print(f"{col} - Variance: {df_clean[col].var():.2f}")
    print(f"{col} - Standard Deviation: {df_clean[col].std():.2f}\n")
# Out:
# Winner_Age - Variance: 14.22
# Winner_Age - Standard Deviation: 3.77
#
# Loser_Age - Variance: 13.05
# Loser_Age - Standard Deviation: 3.61
#
# Winner_Height - Variance: 43.22
# Winner_Height - Standard Deviation: 6.57
#
# Loser_Height - Variance: 48.05
# Loser_Height - Standard Deviation: 6.93
#
# Winner_Rank - Variance: 301.75
# Winner_Rank - Standard Deviation: 17.37
#
# Loser_Rank - Variance: 516.58
# Loser_Rank - Standard Deviation: 22.73

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Only for 'Rank'
feature = 'Rank'

#Winner Rank by Surface (unfiltered)
plt.figure()
sns.boxplot(data=df_clean, x='Surface', y=f'Winner_{feature}', color='blue')
plt.title(f'Winner {feature} by Surface (Unfiltered)')
plt.savefig(f'Winner_{feature}_by_Surface_Unfiltered.png')
plt.show()

#Loser Rank by Surface (unfiltered)
plt.figure()
sns.boxplot(data=df_clean, x='Surface', y=f'Loser_{feature}', color='green')
plt.title(f'Loser {feature} by Surface (Unfiltered)')
plt.savefig(f'Loser_{feature}_by_Surface_Unfiltered.png')
plt.show()

# %%
#Filer the ranking to under 250

import seaborn as sns
import matplotlib.pyplot as plt

# Define df_filtered without palyers worse than 250
df_filtered = df_clean[df_clean['Loser_Rank'] <= 250]

for feature in ['Age', 'Height', 'Rank']:
    #Winner plots
    plt.figure()
    sns.boxplot(data=df_clean, x='Surface', y=f'Winner_{feature}', color='blue')
    plt.title(f'Winner {feature} by Surface')
    plt.savefig(f'Winner_{feature}_by_Surface.png')
    plt.show()

    #Loser plots
    plt.figure()
    if feature == 'Rank':
        # Use filtered data for Rank
        sns.boxplot(data=df_filtered, x='Surface', y=f'Loser_{feature}', color='green')
    else:
        #Use original data for Age and Height
        sns.boxplot(data=df_clean, x='Surface', y=f'Loser_{feature}', color='green')
    
    plt.title(f'Loser {feature} by Surface')
    plt.savefig(f'Loser_{feature}_by_Surface.png')
    plt.show()

# %%
df_clean.groupby('Surface')['Match_Duration_Minutes'].describe()
# Out:
#           count        mean        std   min   25%    50%     75%    max
# Surface
# Carpet    486.0   98.179012  32.676529  11.0  74.0   94.0  117.00  226.0
# Clay     2391.0  113.566290  43.633982   9.0  81.0  106.0  138.00  314.0
# Grass     718.0  123.816156  50.802290  21.0  86.0  115.0  152.75  396.0
# Hard     4669.0  110.009638  42.669096   7.0  79.0  102.0  131.00  353.0

# %%
#Match duration by surface

sns.boxplot(x='Surface', y='Match_Duration_Minutes', data=df_clean)
plt.title('Match Duration by Surface')
plt.ylabel('Minutes')
plt.savefig('Match duration by Surface')
plt.show()

# %%
#Define Best of 3 matches
df_best3 = df_clean[df_clean['Best_Of_Sets'] == 3]

#Define Best of 5 matches
df_best5 = df_clean[df_clean['Best_Of_Sets'] == 5]


#Best of 3 sets summary by surface
print("Best of 3 Sets - Match Duration Summary by Surface:")
print(df_best3.groupby('Surface')['Match_Duration_Minutes'].describe())
print("\n")

# Best of 5 sets summary by surface
print("Best of 5 Sets - Match Duration Summary by Surface:")
print(df_best5.groupby('Surface')['Match_Duration_Minutes'].describe())
# Out:
# Best of 3 Sets - Match Duration Summary by Surface:
#           count        mean        std   min   25%   50%     75%    max
# Surface
# Carpet    454.0   94.577093  28.983089  11.0  73.0  92.0  112.75  194.0
# Clay     1950.0  102.652308  33.957268   9.0  76.0  96.5  126.00  243.0
# Grass     379.0   95.356201  30.525075  21.0  73.0  91.0  115.00  266.0
# Hard     3854.0   99.318111  31.087654   7.0  76.0  94.0  120.00  282.0
#
#
# Best of 5 Sets - Match Duration Summary by Surface:
#          count        mean        std   min    25%    50%    75%    max
# Surface
# Carpet    32.0  149.281250  39.298883  85.0  115.0  157.0  168.0  226.0
# Clay     441.0  161.825397  48.702659  29.0  123.0  155.0  192.0  314.0
# Grass    339.0  155.634218  50.091474  23.0  118.0  151.0  182.0  396.0
# Hard     815.0  160.568098  52.589995  38.0  121.0  152.0  199.5  353.0

# %%
#Separate Best of 3 matches
df_best3 = df_clean[df_clean['Best_Of_Sets'] == 3]

#Separate Best of 5 matches
df_best5 = df_clean[df_clean['Best_Of_Sets'] == 5]

#Best of 3
plt.figure(figsize=(8,6))
sns.boxplot(x='Surface', y='Match_Duration_Minutes', data=df_best3)
plt.title('Match Duration by Surface (Best of 3 Sets)')
plt.ylabel('Minutes')
plt.savefig('Match_Duration_by_Surface_BestOf3.png', dpi=300)
plt.show()

#Best of 5
plt.figure(figsize=(8,6))
sns.boxplot(x='Surface', y='Match_Duration_Minutes', data=df_best5)
plt.title('Match Duration by Surface (Best of 5 Sets)')
plt.ylabel('Minutes')
plt.savefig('Match_Duration_by_Surface_BestOf5.png', dpi=300)
plt.show()

# %%
print("Best of 3 - Mean Match Duration:", df_best3['Match_Duration_Minutes'].mean())
print("Best of 5 - Mean Match Duration:", df_best5['Match_Duration_Minutes'].mean())
# Out:
# Best of 3 - Mean Match Duration: 99.74717492843152
# Best of 5 - Mean Match Duration: 159.65888137676706

# %%
#Best of 3 sets summary by surface
print("Best of 3 Sets - Match Duration Summary by Surface:")
print(df_best3.groupby('Surface')['Match_Duration_Minutes'].describe())
print("\n")

#Best of 5 sets summary by surface
print("Best of 5 Sets - Match Duration Summary by Surface:")
print(df_best5.groupby('Surface')['Match_Duration_Minutes'].describe())
# Out:
# Best of 3 Sets - Match Duration Summary by Surface:
#           count        mean        std   min   25%   50%     75%    max
# Surface
# Carpet    454.0   94.577093  28.983089  11.0  73.0  92.0  112.75  194.0
# Clay     1950.0  102.652308  33.957268   9.0  76.0  96.5  126.00  243.0
# Grass     379.0   95.356201  30.525075  21.0  73.0  91.0  115.00  266.0
# Hard     3854.0   99.318111  31.087654   7.0  76.0  94.0  120.00  282.0
#
#
# Best of 5 Sets - Match Duration Summary by Surface:
#          count        mean        std   min    25%    50%    75%    max
# Surface
# Carpet    32.0  149.281250  39.298883  85.0  115.0  157.0  168.0  226.0
# Clay     441.0  161.825397  48.702659  29.0  123.0  155.0  192.0  314.0
# Grass    339.0  155.634218  50.091474  23.0  118.0  151.0  182.0  396.0
# Hard     815.0  160.568098  52.589995  38.0  121.0  152.0  199.5  353.0

# %%
#Bar graph for match duration on dif surfaces

plt.figure(figsize=(8,6))
sns.barplot(data=df_best3, x='Surface', y='Match_Duration_Minutes', palette='pastel')
plt.title('Average Match Duration by Surface (Best of 3 Sets)')
plt.xlabel('Surface')
plt.ylabel('Average Match Duration (Minutes)')
plt.savefig('Average Match Duration by Surface (Best of 3 Sets)')
plt.show()

plt.figure(figsize=(8,6))
sns.barplot(data=df_best5, x='Surface', y='Match_Duration_Minutes', palette='pastel')
plt.title('Average Match Duration by Surface (Best of 5 Sets)')
plt.xlabel('Surface')
plt.ylabel('Average Match Duration (Minutes)')
plt.savefig('Average Match Duration by Surface (Best of 5 Sets)')
plt.show()
# Out:
# C:\Users\jacov\AppData\Local\Temp\ipykernel_1976\2071243326.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_best3, x='Surface', y='Match_Duration_Minutes', palette='pastel')
# C:\Users\jacov\AppData\Local\Temp\ipykernel_1976\2071243326.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_best5, x='Surface', y='Match_Duration_Minutes', palette='pastel')

# %%
#Violin plot for match duration

plt.figure(figsize=(8,6))
sns.violinplot(x='Surface', y='Match_Duration_Minutes', data=df_best3)
plt.title('Match Duration by Surface (Violin Plot)')
plt.savefig('Match duration violin plot')
plt.show()

# %%
#Serve stats 

serve_columns = [
    ('Winner_Aces', 'Loser_Aces'),
    ('Winner_DoubleFaults', 'Loser_DoubleFaults'),
    ('Winner_FirstServeWon', 'Loser_FirstServeWon'),
    ('Winner_SecondServeWon', 'Loser_SecondServeWon'),
    ('Winner_BreakPointsSaved', 'Loser_BreakPointsSaved')
]

for winner_col, loser_col in serve_columns:
    print(f"{winner_col} - Mean: {df_clean[winner_col].mean():.2f}")
    print(f"{loser_col} - Mean: {df_clean[loser_col].mean():.2f}\n")
# Out:
# Winner_Aces - Mean: 7.11
# Loser_Aces - Mean: 5.58
#
# Winner_DoubleFaults - Mean: 2.49
# Loser_DoubleFaults - Mean: 3.14
#
# Winner_FirstServeWon - Mean: 37.39
# Loser_FirstServeWon - Mean: 33.55
#
# Winner_SecondServeWon - Mean: 16.89
# Loser_SecondServeWon - Mean: 15.24
#
# Winner_BreakPointsSaved - Mean: 3.51
# Loser_BreakPointsSaved - Mean: 4.77

# %%
#Histogram of match duration

plt.figure(figsize=(8,6))
sns.histplot(df_best3['Match_Duration_Minutes'], bins=50, kde=False, color='purple')
plt.title('Histogram of Match Duration')
plt.xlabel('Minutes')
plt.savefig('Histogram of match duration')
plt.show()

#KDE of match duration
plt.figure(figsize=(8,6))
sns.kdeplot(df_best3['Match_Duration_Minutes'], fill=True, color='purple')
plt.title('KDE of Match Duration')
plt.xlabel('Minutes')
plt.savefig('KDE of match duration')
plt.show()

#Boxplot for match duration
plt.figure(figsize=(8,6))
sns.boxplot(y='Match_Duration_Minutes', data=df_best3, color='purple')
plt.title('Boxplot of Match Duration')
plt.ylabel('Minutes')
plt.show()

# %%
#Serve stats

sns.scatterplot(x='Winner_Aces', y='Winner_DoubleFaults', data=df_clean, color='blue', label='Winner')
sns.scatterplot(x='Loser_Aces', y='Loser_DoubleFaults', data=df_clean, color='red', label='Loser')
plt.title('Aces vs Double Faults (Winner vs Loser)')
plt.show()

# %%
plt.figure(figsize=(8,8))
ax = sns.scatterplot(x='Winner_Aces', y='Winner_DoubleFaults', data=df_clean, color='blue', label='Winner')
sns.scatterplot(x='Loser_Aces', y='Loser_DoubleFaults', data=df_clean, color='red', label='Loser', ax=ax)

ax.set_aspect('equal', adjustable='box')
ax.set_title('Aces vs Double Faults (Winner vs Loser)')
ax.set_xlabel('Number of Aces')
ax.set_ylabel('Number of Double Faults')

plt.savefig('ScatterPlot Aces vs Double faults')
plt.show()

# %%
#Heatmat showing correlation matrix

#Numerical columns for  Best of 3 dataset
numerics_best3 = df_best3[['Winner_Aces', 'Loser_Aces',
                           'Winner_DoubleFaults', 'Loser_DoubleFaults',
                           'Winner_FirstServeWon', 'Loser_FirstServeWon',
                           'Winner_SecondServeWon', 'Loser_SecondServeWon',
                           'Winner_Rank', 'Loser_Rank',
                           'Match_Duration_Minutes']]

#Calculate correlation matrix
correlation_best3 = numerics_best3.corr()
print("Correlation Matrix for Best of 3 Matches:\n", correlation_best3)


plt.figure(figsize=(10, 8)) 
ax = sns.heatmap(correlation_best3, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Best of 3 Matches)", pad=20)

ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)

plt.tight_layout()  
plt.savefig('Heatmap_Serving_Correlation_BestOf3.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Correlation Matrix for Best of 3 Matches:
#                          Winner_Aces  Loser_Aces  Winner_DoubleFaults  \
# Winner_Aces                1.000000    0.292116             0.206216
# Loser_Aces                 0.292116    1.000000             0.152539
# Winner_DoubleFaults        0.206216    0.152539             1.000000
# Loser_DoubleFaults         0.079231    0.186820             0.193646
# Winner_FirstServeWon       0.394828    0.454670             0.295752
# Loser_FirstServeWon        0.358806    0.518370             0.286970
# Winner_SecondServeWon      0.228077    0.333829             0.342134
# Loser_SecondServeWon       0.292257    0.353042             0.309808
# Winner_Rank               -0.029664   -0.051221             0.074239
# Loser_Rank                -0.012097   -0.095612             0.014523
# Match_Duration_Minutes     0.169734    0.316578             0.325428
#
#                         Loser_DoubleFaults  Winner_FirstServeWon  \
# Winner_Aces                       0.079231              0.394828
# Loser_Aces                        0.186820              0.454670
# Winner_DoubleFaults               0.193646              0.295752
# Loser_DoubleFaults                1.000000              0.161369
# Winner_FirstServeWon              0.161369              1.000000
# Loser_FirstServeWon               0.178668              0.799491
# Winner_SecondServeWon             0.194635              0.360339
# Loser_SecondServeWon              0.270679              0.618197
# Winner_Rank                       0.062063              0.017896
# Loser_Rank                        0.029704             -0.052645
# Match_Duration_Minutes            0.189135              0.762064
#
#                         Loser_FirstServeWon  Winner_SecondServeWon  \
# Winner_Aces                        0.358806               0.228077
# Loser_Aces                         0.518370               0.333829
# Winner_DoubleFaults                0.286970               0.342134
# Loser_DoubleFaults                 0.178668               0.194635
# Winner_FirstServeWon               0.799491               0.360339
# Loser_FirstServeWon                1.000000               0.577277
# Winner_SecondServeWon              0.577277               1.000000
# Loser_SecondServeWon               0.508960               0.543975
# Winner_Rank                        0.016168               0.039018
# Loser_Rank                        -0.059026              -0.036674
# Match_Duration_Minutes             0.786277               0.601994
#
#                         Loser_SecondServeWon  Winner_Rank  Loser_Rank  \
# Winner_Aces                         0.292257    -0.029664   -0.012097
# Loser_Aces                          0.353042    -0.051221   -0.095612
# Winner_DoubleFaults                 0.309808     0.074239    0.014523
# Loser_DoubleFaults                  0.270679     0.062063    0.029704
# Winner_FirstServeWon                0.618197     0.017896   -0.052645
# Loser_FirstServeWon                 0.508960     0.016168   -0.059026
# Winner_SecondServeWon               0.543975     0.039018   -0.036674
# Loser_SecondServeWon                1.000000     0.031771   -0.030326
# Winner_Rank                         0.031771     1.000000    0.311578
# Loser_Rank                         -0.030326     0.311578    1.000000
# Match_Duration_Minutes              0.660348     0.004877   -0.097292
#
#                         Match_Duration_Minutes
# Winner_Aces                           0.169734
# Loser_Aces                            0.316578
# Winner_DoubleFaults                   0.325428
# Loser_DoubleFaults                    0.189135
# Winner_FirstServeWon                  0.762064
# Loser_FirstServeWon                   0.786277
# Winner_SecondServeWon                 0.601994
# Loser_SecondServeWon                  0.660348
# Winner_Rank                           0.004877
# Loser_Rank                           -0.097292
# Match_Duration_Minutes                1.000000

# %%
#power BI like dashboard

import matplotlib.pyplot as plt
import seaborn as sns

#Select numeric columns for correlation
numerics_best3 = df_best3[['Winner_Aces', 'Loser_Aces',
                     'Winner_DoubleFaults', 'Loser_DoubleFaults',
                     'Winner_FirstServeWon', 'Loser_FirstServeWon',
                     'Winner_SecondServeWon', 'Loser_SecondServeWon',
                     'Winner_Rank', 'Loser_Rank',
                     'Match_Duration_Minutes']]

correlation = numerics_best3.corr()


#Create 2x2 subplot figure
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

#Plot 1: Match Duration by Surface (Best of 3)
sns.boxplot(x='Surface', y='Match_Duration_Minutes', data=df_best3, ax=axes[0,0])
axes[0,0].set_title('Match Duration by Surface (Best of 3)')
axes[0,0].set_ylabel('Minutes')
axes[0,0].set_xlabel('Surface')

#Plot 2: Heatmap of Correlation
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[0,1])
axes[0,1].set_title('Correlation Heatmap of Serve Stats, Rank & Duration')

#Plot 3: Winner Rank by Surface
sns.boxplot(data=df_clean, x='Surface', y='Winner_Rank', ax=axes[1,0])
axes[1,0].set_title('Winner Rank by Surface')
axes[1,0].set_ylabel('Rank')
axes[1,0].set_xlabel('Surface')

#Plot 4: Loser Rank by Surface (filtered ≤250)
df_filtered = df_clean[df_clean['Loser_Rank'] <= 250]
sns.boxplot(data=df_filtered, x='Surface', y='Loser_Rank', ax=axes[1,1],)
axes[1,1].set_title('Loser Rank by Surface (≤ 250)')
axes[1,1].set_ylabel('Rank')
axes[1,1].set_xlabel('Surface')


plt.tight_layout()
plt.savefig('Tennis_EDA_Dashboard.png', dpi=300)
plt.show()

# %%
#Age violin plot

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.violinplot(data=df_clean, y='Winner_Age', color='skyblue')
plt.title('Violin Plot of Winner Age')
plt.show()

plt.figure(figsize=(8,6))
sns.violinplot(data=df_clean, y='Loser_Age', color='lightgreen')
plt.title('Violin Plot of Loser Age')
plt.show()

# %%
#Skewness and Kurtosis

from scipy.stats import skew, kurtosis

for col in ['Winner_Age', 'Loser_Age', 'Winner_Rank', 'Loser_Rank', 'Match_Duration_Minutes']:
    print(f"{col} - Skewness: {skew(df_best3[col]):.2f}")
    print(f"{col} - Kurtosis: {kurtosis(df_best3[col]):.2f}\n")
# Out:
# Winner_Age - Skewness: 0.54
# Winner_Age - Kurtosis: 0.09
#
# Loser_Age - Skewness: 0.43
# Loser_Age - Kurtosis: -0.08
#
# Winner_Rank - Skewness: 1.91
# Winner_Rank - Kurtosis: 5.19
#
# Loser_Rank - Skewness: 8.06
# Loser_Rank - Kurtosis: 169.95
#
# Match_Duration_Minutes - Skewness: 0.66
# Match_Duration_Minutes - Kurtosis: 0.39

# %%
#outliers best of 3

from scipy.stats import zscore

z_scores = zscore(df_best3[['Winner_Age', 'Loser_Age', 'Winner_Rank', 'Loser_Rank', 'Match_Duration_Minutes']])

outliers = df_best3[(abs(z_scores) > 3).any(axis=1)]
print(f"Number of outliers detected: {outliers.shape[0]}")
# Out:
# Number of outliers detected: 236

# %%
#outliers best of 5
from scipy.stats import zscore

z_scores = zscore(df_best5[['Winner_Age', 'Loser_Age', 'Winner_Rank', 'Loser_Rank', 'Match_Duration_Minutes']])

outliers = df_best5[(abs(z_scores) > 3).any(axis=1)]
print(f"Number of outliers detected: {outliers.shape[0]}")
# Out:
# Number of outliers detected: 34

# %%
#Serve stats aces vs double faults

plt.figure(figsize=(8,6))
sns.scatterplot(x='Winner_Aces', y='Winner_DoubleFaults', data=df_best3, color='blue')
plt.title('Winner Aces vs Winner Double Faults')
plt.xlabel('Winner Aces')
plt.ylabel('Winner Double Faults')
plt.savefig('Scatterplot - Aces vs Double faults')
plt.show()

# %%
#Added regression line

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.regplot(x='Winner_Aces', y='Winner_DoubleFaults', data=df_best3, scatter_kws={'color':'blue'}, line_kws={'color':'red'})
plt.title('Regression Line: Winner Aces vs Winner Double Faults (Best of 3)')
plt.xlabel('Winner Aces')
plt.ylabel('Winner Double Faults')
plt.show()

# %%
#correlation calc

from scipy.stats import pearsonr
from scipy.stats import spearmanr

#Pearson
pearson_corr, p_value = pearsonr(df_best3['Winner_Aces'], df_best3['Winner_DoubleFaults'])

print(f"Pearson Correlation Coefficient: {pearson_corr:.2f}")
print(f"P-value: {p_value:.4f}")

#Spearman
spearman_corr, p_value_spearman = spearmanr(df_best3['Winner_Aces'], df_best3['Winner_DoubleFaults'])

print(f"Spearman Correlation Coefficient: {spearman_corr:.2f}")
print(f"P-value: {p_value_spearman:.4f}")
# Out:
# Pearson Correlation Coefficient: 0.21
# P-value: 0.0000
# Spearman Correlation Coefficient: 0.20
# P-value: 0.0000

# %%
#Hieght vs Aces correlation

#Scatterplot
plt.figure(figsize=(8,6))
sns.scatterplot(x='Winner_Height', y='Winner_Aces', data=df_best3, color='orange')
plt.title('Winner Height vs Winner Aces')
plt.show()

#Regression Plot
plt.figure(figsize=(8,6))
sns.regplot(x='Winner_Height', y='Winner_Aces', data=df_clean, scatter_kws={'color':'orange'}, line_kws={'color':'black'})
plt.title('Regression: Winner Height vs Winner Aces')
plt.savefig('Scatterplot Winner height vs Winner aces')
plt.show()

# %%
#First serve vs second serve relationship

#Scatterplot
plt.figure(figsize=(8,6))
sns.scatterplot(x='Winner_FirstServeWon', y='Winner_SecondServeWon', data=df_best3, color='teal')
plt.title('Winner First Serve Won vs Second Serve Won')
plt.show()

#Pearson Correlation
from scipy.stats import pearsonr

pearson, p_value = pearsonr(df_best3['Winner_FirstServeWon'], df_best3['Winner_SecondServeWon'])
print(f"Pearson Correlation Coefficient: {pearson:.2f}")
print(f"P-value: {p_value:.4f}")


#Spearman Correlation
spearman_corr, p_value_spearman = spearmanr(df_best3['Winner_FirstServeWon'], df_best3['Winner_SecondServeWon'])

print(f"Spearman Correlation Coefficient: {spearman_corr:.2f}")
print(f"P-value: {p_value_spearman:.4f}")
# Out:
# Pearson Correlation Coefficient: 0.36
# P-value: 0.0000
# Spearman Correlation Coefficient: 0.34
# P-value: 0.0000

# %%
#First serve vs second serve relationship (regression line)

plt.figure(figsize=(8,6))
sns.regplot(x='Winner_FirstServeWon', y='Winner_SecondServeWon', 
            data=df_best3, 
            scatter_kws={'color':'teal'}, 
            line_kws={'color':'red'})

plt.title('Regression Line: First Serve Won vs Second Serve Won (Best of 3)')
plt.xlabel('Winner First Serve Won')
plt.ylabel('Winner Second Serve Won')

#x and y axes have the same scale
plt.gca().set_aspect('equal', adjustable='datalim')
plt.savefig('Scatterplot First serve won vs second serve won')
plt.show()

# %%
#Outliers

import numpy as np
from scipy.stats import zscore

#Z score

#Numeric columns to check
numeric_cols = ['Winner_Rank', 'Loser_Rank',
                'Winner_Aces', 'Loser_Aces',
                'Winner_DoubleFaults', 'Loser_DoubleFaults',
                'Match_Duration_Minutes']

#Function to calculate Z-score outliers for any dataset
def detect_outliers_zscore(df_subset, threshold=3):
    df_numeric = df_subset[numeric_cols].dropna()
    z_scores = np.abs(zscore(df_numeric))
    outliers = (z_scores > threshold).any(axis=1)
    
    outlier_count = outliers.sum()
    df_outliers = df_subset.loc[df_numeric.index[outliers]]
    
    return outlier_count, df_outliers

#Best of 3 matches
outlier_count_best3, df_best3_outliers = detect_outliers_zscore(df_best3)
print(f"Number of outliers in Best of 3 dataset: {outlier_count_best3}")

#Best of 5 matches
outlier_count_best5, df_best5_outliers = detect_outliers_zscore(df_best5)
print(f"Number of outliers in Best of 5 dataset: {outlier_count_best5}")

#View first few outliers
print("\nSample Outliers in Best of 3:")
print(df_best3_outliers.head())

print("\nSample Outliers in Best of 5:")
print(df_best5_outliers.head())
# Out:
# Number of outliers in Best of 3 dataset: 491
# Number of outliers in Best of 5 dataset: 112
#
# Sample Outliers in Best of 3:
#       Tournament_ID Tournament_Name Surface  Draw_Size Tournament_Level  \
# 86659      1991-403   Miami Masters    Hard         96                M
# 87266      1991-436       Charlotte    Clay         32                A
# 87272      1991-436       Charlotte    Clay         32                A
# 87791      1991-306          Genova    Clay         32                A
# 87797      1991-306          Genova    Clay         32                A
#
#        Tournament_Date  Match_Number  Winner_ID  Winner_Seed Winner_Entry  \
# 86659         19910315            81     101222          1.0          NaN
# 87266         19910506            25     101409          7.0          NaN
# 87272         19910506            31     101409          7.0          NaN
# 87791         19910617            25     101391          7.0          NaN
# 87797         19910617            31     101391          7.0          NaN
#
#           Winner_Name Winner_Hand  Winner_Height Winner_Country  Winner_Age  \
# 86659   Stefan Edberg           R          188.0            SWE        25.1
# 87266     Jaime Yzaga           R          170.0            PER        23.5
# 87272     Jaime Yzaga           R          170.0            PER        23.5
# 87791  Carl Uwe Steeb           L          180.0            GER        23.7
# 87797  Carl Uwe Steeb           L          180.0            GER        23.7
#
#        Loser_ID  Loser_Seed Loser_Entry     Loser_Name Loser_Hand  \
# 86659    101529        15.0         NaN  Michael Stich          R
# 87266    102021         1.0         NaN  Michael Chang          R
# 87272    101061         5.0         NaN    Jimmy Arias          R
# 87791    101086         1.0         NaN  Ronald Agenor          R
# 87797    101063         3.0         NaN   Jordi Arrese          R
#
#        Loser_Height Loser_Country  Loser_Age  Match_Score  Best_Of_Sets Round  \
# 86659         193.0           GER       22.3  6-4 2-6 6-4             3   R16
# 87266         175.0           USA       19.2   7-6(0) 6-1             3    QF
# 87272         175.0           USA       26.7      6-3 7-5             3     F
# 87791         180.0           USA       26.5      6-1 6-4             3    QF
# 87797         175.0           ESP       26.7      6-3 6-4             3     F
#
#        Match_Duration_Minutes  Winner_Aces  Winner_DoubleFaults  \
# 86659                   118.0          0.0                  9.0
# 87266                    94.0          1.0                  0.0
# 87272                   120.0          1.0                  1.0
# 87791                    90.0          5.0                  1.0
# 87797                   108.0          3.0                  0.0
#
#        Winner_ServePoints  Winner_FirstServeIn  Winner_FirstServeWon  \
# 86659                92.0                 66.0                  45.0
# 87266                63.0                 40.0                  25.0
# 87272                84.0                 47.0                  33.0
# 87791                61.0                 31.0                  21.0
# 87797                87.0                 52.0                  36.0
#
#        Winner_SecondServeWon  Winner_ServiceGames  Winner_BreakPointsSaved  \
# 86659                   12.0                 14.0                      8.0
# 87266                   12.0                 10.0                      3.0
# 87272                   17.0                 10.0                     12.0
# 87791                   15.0                  8.0                      3.0
# 87797                   18.0                 10.0                     11.0
#
#        Winner_BreakPointsFaced  Loser_Aces  Loser_DoubleFaults  \
# 86659                     10.0         4.0                 2.0
# 87266                      6.0         1.0                 1.0
# 87272                     14.0         1.0                 0.0
# 87791                      5.0         0.0                 3.0
# 87797                     11.0         1.0                 0.0
#
#        Loser_ServePoints  Loser_FirstServeIn  Loser_FirstServeWon  \
# 86659               97.0                62.0                 43.0
# 87266               54.0                26.0                 15.0
# 87272               78.0                56.0                 29.0
# 87791               52.0                35.0                 18.0
# 87797               61.0                55.0                 34.0
#
#        Loser_SecondServeWon  Loser_ServiceGames  Loser_BreakPointsSaved  \
# 86659                  18.0                14.0                     5.0
# 87266                  10.0                 9.0                     3.0
# 87272                  11.0                11.0                    10.0
# 87791                   4.0                 9.0                     4.0
# 87797                   4.0                 9.0                     4.0
#
#        Loser_BreakPointsFaced  Winner_Rank  Winner_Rank_Points  Loser_Rank  \
# 86659                     7.0          1.0              3846.0        20.0
# 87266                     8.0         76.0               481.0        10.0
# 87272                    15.0         76.0               481.0        58.0
# 87791                    10.0         75.0               494.0        28.0
# 87797                     6.0         75.0               494.0        41.0
#
#        Loser_Rank_Points
# 86659             1079.0
# 87266             1426.0
# 87272              549.0
# 87791              890.0
# 87797              666.0
#
# Sample Outliers in Best of 5:
#       Tournament_ID   Tournament_Name Surface  Draw_Size Tournament_Level  \
# 90161      1992-357  Stuttgart Indoor  Carpet         32                A
# 91673      1992-540         Wimbledon   Grass        128                G
# 91675      1992-540         Wimbledon   Grass        128                G
# 91676      1992-540         Wimbledon   Grass        128                G
# 92568      1992-560           US Open    Hard        128                G
#
#        Tournament_Date  Match_Number  Winner_ID  Winner_Seed Winner_Entry  \
# 90161         19920217            31     101964          7.0          NaN
# 91673         19920622           124     101964          8.0          NaN
# 91675         19920622           126     101964          8.0          NaN
# 91676         19920622           127     101736         12.0          NaN
# 92568         19920831           119     100656          9.0          NaN
#
#             Winner_Name Winner_Hand  Winner_Height Winner_Country  Winner_Age  \
# 90161  Goran Ivanisevic           L          193.0            CRO        20.4
# 91673  Goran Ivanisevic           L          193.0            CRO        20.7
# 91675  Goran Ivanisevic           L          193.0            CRO        20.7
# 91676      Andre Agassi           R          180.0            USA        22.1
# 92568        Ivan Lendl           R          188.0            USA        32.4
#
#        Loser_ID  Loser_Seed Loser_Entry        Loser_Name Loser_Hand  \
# 90161    101222         2.0         NaN     Stefan Edberg          R
# 91673    101222         2.0         NaN     Stefan Edberg          R
# 91675    101948         5.0         NaN      Pete Sampras          R
# 91676    101964         8.0         NaN  Goran Ivanisevic          L
# 92568    101414         7.0         NaN      Boris Becker          R
#
#        Loser_Height Loser_Country  Loser_Age                Match_Score  \
# 90161         188.0           SWE       26.0         6-7(5) 6-3 6-4 6-4
# 91673         188.0           SWE       26.4    6-7(10) 7-5 6-1 3-6 6-3
# 91675         185.0           USA       20.8      6-7(4) 7-6(5) 6-4 6-2
# 91676         193.0           CRO       20.7     6-7(8) 6-4 6-4 1-6 6-4
# 92568         190.0           GER       24.7  6-7(4) 6-2 6-7(4) 6-3 6-4
#
#        Best_Of_Sets Round  Match_Duration_Minutes  Winner_Aces  \
# 90161             5     F                   166.0         32.0
# 91673             5    QF                   176.0         33.0
# 91675             5    SF                   132.0         36.0
# 91676             5     F                   170.0          9.0
# 92568             5   R16                   301.0         10.0
#
#        Winner_DoubleFaults  Winner_ServePoints  Winner_FirstServeIn  \
# 90161                  4.0               143.0                 71.0
# 91673                  7.0               192.0                137.0
# 91675                  5.0               159.0                105.0
# 91676                  1.0               166.0                115.0
# 92568                  4.0               186.0                115.0
#
#        Winner_FirstServeWon  Winner_SecondServeWon  Winner_ServiceGames  \
# 90161                  61.0                   37.0                 21.0
# 91673                 119.0                   27.0                 25.0
# 91675                  96.0                   32.0                 21.0
# 91676                  89.0                   31.0                 24.0
# 92568                  90.0                   35.0                 26.0
#
#        Winner_BreakPointsSaved  Winner_BreakPointsFaced  Loser_Aces  \
# 90161                      7.0                      8.0         5.0
# 91673                      6.0                      7.0         6.0
# 91675                      0.0                      0.0        13.0
# 91676                      3.0                      5.0        37.0
# 92568                      5.0                      7.0        19.0
#
#        Loser_DoubleFaults  Loser_ServePoints  Loser_FirstServeIn  \
# 90161                 2.0              141.0               109.0
# 91673                 9.0              178.0               101.0
# 91675                 7.0              150.0                87.0
# 91676                 7.0              208.0               139.0
# 92568                13.0              226.0               117.0
#
#        Loser_FirstServeWon  Loser_SecondServeWon  Loser_ServiceGames  \
# 90161                 73.0                  16.0                20.0
# 91673                 77.0                  36.0                24.0
# 91675                 71.0                  31.0                21.0
# 91676                120.0                  29.0                25.0
# 92568                 85.0                  51.0                25.0
#
#        Loser_BreakPointsSaved  Loser_BreakPointsFaced  Winner_Rank  \
# 90161                     8.0                    12.0          9.0
# 91673                     9.0                    13.0          8.0
# 91675                     2.0                     5.0          8.0
# 91676                    13.0                    16.0         14.0
# 92568                    16.0                    22.0          7.0
#
#        Winner_Rank_Points  Loser_Rank  Loser_Rank_Points
# 90161              1590.0         2.0             3698.0
# 91673              1837.0         2.0             3327.0
# 91675              1837.0         3.0             2760.0
# 91676              1345.0         8.0             1837.0
# 92568              2016.0         8.0             1918.0

# %%
#Outliers with %

#Count total records
total_best3 = len(df_best3)
total_best5 = len(df_best5)

#Best of 3 matches
outlier_count_best3, df_best3_outliers = detect_outliers_zscore(df_best3)
percent_outliers_best3 = (outlier_count_best3 / total_best3) * 100
print(f"Number of outliers in Best of 3 dataset: {outlier_count_best3} out of {total_best3} ({percent_outliers_best3:.2f}%)")

#Best of 5 matches
outlier_count_best5, df_best5_outliers = detect_outliers_zscore(df_best5)
percent_outliers_best5 = (outlier_count_best5 / total_best5) * 100
print(f"Number of outliers in Best of 5 dataset: {outlier_count_best5} out of {total_best5} ({percent_outliers_best5:.2f}%)")

#View first few outliers
print("\nSample Outliers in Best of 3:")
print(df_best3_outliers.head())

print("\nSample Outliers in Best of 5:")
print(df_best5_outliers.head())
# Out:
# Number of outliers in Best of 3 dataset: 491 out of 6637 (7.40%)
# Number of outliers in Best of 5 dataset: 112 out of 1627 (6.88%)
#
# Sample Outliers in Best of 3:
#       Tournament_ID Tournament_Name Surface  Draw_Size Tournament_Level  \
# 86659      1991-403   Miami Masters    Hard         96                M
# 87266      1991-436       Charlotte    Clay         32                A
# 87272      1991-436       Charlotte    Clay         32                A
# 87791      1991-306          Genova    Clay         32                A
# 87797      1991-306          Genova    Clay         32                A
#
#        Tournament_Date  Match_Number  Winner_ID  Winner_Seed Winner_Entry  \
# 86659         19910315            81     101222          1.0          NaN
# 87266         19910506            25     101409          7.0          NaN
# 87272         19910506            31     101409          7.0          NaN
# 87791         19910617            25     101391          7.0          NaN
# 87797         19910617            31     101391          7.0          NaN
#
#           Winner_Name Winner_Hand  Winner_Height Winner_Country  Winner_Age  \
# 86659   Stefan Edberg           R          188.0            SWE        25.1
# 87266     Jaime Yzaga           R          170.0            PER        23.5
# 87272     Jaime Yzaga           R          170.0            PER        23.5
# 87791  Carl Uwe Steeb           L          180.0            GER        23.7
# 87797  Carl Uwe Steeb           L          180.0            GER        23.7
#
#        Loser_ID  Loser_Seed Loser_Entry     Loser_Name Loser_Hand  \
# 86659    101529        15.0         NaN  Michael Stich          R
# 87266    102021         1.0         NaN  Michael Chang          R
# 87272    101061         5.0         NaN    Jimmy Arias          R
# 87791    101086         1.0         NaN  Ronald Agenor          R
# 87797    101063         3.0         NaN   Jordi Arrese          R
#
#        Loser_Height Loser_Country  Loser_Age  Match_Score  Best_Of_Sets Round  \
# 86659         193.0           GER       22.3  6-4 2-6 6-4             3   R16
# 87266         175.0           USA       19.2   7-6(0) 6-1             3    QF
# 87272         175.0           USA       26.7      6-3 7-5             3     F
# 87791         180.0           USA       26.5      6-1 6-4             3    QF
# 87797         175.0           ESP       26.7      6-3 6-4             3     F
#
#        Match_Duration_Minutes  Winner_Aces  Winner_DoubleFaults  \
# 86659                   118.0          0.0                  9.0
# 87266                    94.0          1.0                  0.0
# 87272                   120.0          1.0                  1.0
# 87791                    90.0          5.0                  1.0
# 87797                   108.0          3.0                  0.0
#
#        Winner_ServePoints  Winner_FirstServeIn  Winner_FirstServeWon  \
# 86659                92.0                 66.0                  45.0
# 87266                63.0                 40.0                  25.0
# 87272                84.0                 47.0                  33.0
# 87791                61.0                 31.0                  21.0
# 87797                87.0                 52.0                  36.0
#
#        Winner_SecondServeWon  Winner_ServiceGames  Winner_BreakPointsSaved  \
# 86659                   12.0                 14.0                      8.0
# 87266                   12.0                 10.0                      3.0
# 87272                   17.0                 10.0                     12.0
# 87791                   15.0                  8.0                      3.0
# 87797                   18.0                 10.0                     11.0
#
#        Winner_BreakPointsFaced  Loser_Aces  Loser_DoubleFaults  \
# 86659                     10.0         4.0                 2.0
# 87266                      6.0         1.0                 1.0
# 87272                     14.0         1.0                 0.0
# 87791                      5.0         0.0                 3.0
# 87797                     11.0         1.0                 0.0
#
#        Loser_ServePoints  Loser_FirstServeIn  Loser_FirstServeWon  \
# 86659               97.0                62.0                 43.0
# 87266               54.0                26.0                 15.0
# 87272               78.0                56.0                 29.0
# 87791               52.0                35.0                 18.0
# 87797               61.0                55.0                 34.0
#
#        Loser_SecondServeWon  Loser_ServiceGames  Loser_BreakPointsSaved  \
# 86659                  18.0                14.0                     5.0
# 87266                  10.0                 9.0                     3.0
# 87272                  11.0                11.0                    10.0
# 87791                   4.0                 9.0                     4.0
# 87797                   4.0                 9.0                     4.0
#
#        Loser_BreakPointsFaced  Winner_Rank  Winner_Rank_Points  Loser_Rank  \
# 86659                     7.0          1.0              3846.0        20.0
# 87266                     8.0         76.0               481.0        10.0
# 87272                    15.0         76.0               481.0        58.0
# 87791                    10.0         75.0               494.0        28.0
# 87797                     6.0         75.0               494.0        41.0
#
#        Loser_Rank_Points
# 86659             1079.0
# 87266             1426.0
# 87272              549.0
# 87791              890.0
# 87797              666.0
#
# Sample Outliers in Best of 5:
#       Tournament_ID   Tournament_Name Surface  Draw_Size Tournament_Level  \
# 90161      1992-357  Stuttgart Indoor  Carpet         32                A
# 91673      1992-540         Wimbledon   Grass        128                G
# 91675      1992-540         Wimbledon   Grass        128                G
# 91676      1992-540         Wimbledon   Grass        128                G
# 92568      1992-560           US Open    Hard        128                G
#
#        Tournament_Date  Match_Number  Winner_ID  Winner_Seed Winner_Entry  \
# 90161         19920217            31     101964          7.0          NaN
# 91673         19920622           124     101964          8.0          NaN
# 91675         19920622           126     101964          8.0          NaN
# 91676         19920622           127     101736         12.0          NaN
# 92568         19920831           119     100656          9.0          NaN
#
#             Winner_Name Winner_Hand  Winner_Height Winner_Country  Winner_Age  \
# 90161  Goran Ivanisevic           L          193.0            CRO        20.4
# 91673  Goran Ivanisevic           L          193.0            CRO        20.7
# 91675  Goran Ivanisevic           L          193.0            CRO        20.7
# 91676      Andre Agassi           R          180.0            USA        22.1
# 92568        Ivan Lendl           R          188.0            USA        32.4
#
#        Loser_ID  Loser_Seed Loser_Entry        Loser_Name Loser_Hand  \
# 90161    101222         2.0         NaN     Stefan Edberg          R
# 91673    101222         2.0         NaN     Stefan Edberg          R
# 91675    101948         5.0         NaN      Pete Sampras          R
# 91676    101964         8.0         NaN  Goran Ivanisevic          L
# 92568    101414         7.0         NaN      Boris Becker          R
#
#        Loser_Height Loser_Country  Loser_Age                Match_Score  \
# 90161         188.0           SWE       26.0         6-7(5) 6-3 6-4 6-4
# 91673         188.0           SWE       26.4    6-7(10) 7-5 6-1 3-6 6-3
# 91675         185.0           USA       20.8      6-7(4) 7-6(5) 6-4 6-2
# 91676         193.0           CRO       20.7     6-7(8) 6-4 6-4 1-6 6-4
# 92568         190.0           GER       24.7  6-7(4) 6-2 6-7(4) 6-3 6-4
#
#        Best_Of_Sets Round  Match_Duration_Minutes  Winner_Aces  \
# 90161             5     F                   166.0         32.0
# 91673             5    QF                   176.0         33.0
# 91675             5    SF                   132.0         36.0
# 91676             5     F                   170.0          9.0
# 92568             5   R16                   301.0         10.0
#
#        Winner_DoubleFaults  Winner_ServePoints  Winner_FirstServeIn  \
# 90161                  4.0               143.0                 71.0
# 91673                  7.0               192.0                137.0
# 91675                  5.0               159.0                105.0
# 91676                  1.0               166.0                115.0
# 92568                  4.0               186.0                115.0
#
#        Winner_FirstServeWon  Winner_SecondServeWon  Winner_ServiceGames  \
# 90161                  61.0                   37.0                 21.0
# 91673                 119.0                   27.0                 25.0
# 91675                  96.0                   32.0                 21.0
# 91676                  89.0                   31.0                 24.0
# 92568                  90.0                   35.0                 26.0
#
#        Winner_BreakPointsSaved  Winner_BreakPointsFaced  Loser_Aces  \
# 90161                      7.0                      8.0         5.0
# 91673                      6.0                      7.0         6.0
# 91675                      0.0                      0.0        13.0
# 91676                      3.0                      5.0        37.0
# 92568                      5.0                      7.0        19.0
#
#        Loser_DoubleFaults  Loser_ServePoints  Loser_FirstServeIn  \
# 90161                 2.0              141.0               109.0
# 91673                 9.0              178.0               101.0
# 91675                 7.0              150.0                87.0
# 91676                 7.0              208.0               139.0
# 92568                13.0              226.0               117.0
#
#        Loser_FirstServeWon  Loser_SecondServeWon  Loser_ServiceGames  \
# 90161                 73.0                  16.0                20.0
# 91673                 77.0                  36.0                24.0
# 91675                 71.0                  31.0                21.0
# 91676                120.0                  29.0                25.0
# 92568                 85.0                  51.0                25.0
#
#        Loser_BreakPointsSaved  Loser_BreakPointsFaced  Winner_Rank  \
# 90161                     8.0                    12.0          9.0
# 91673                     9.0                    13.0          8.0
# 91675                     2.0                     5.0          8.0
# 91676                    13.0                    16.0         14.0
# 92568                    16.0                    22.0          7.0
#
#        Winner_Rank_Points  Loser_Rank  Loser_Rank_Points
# 90161              1590.0         2.0             3698.0
# 91673              1837.0         2.0             3327.0
# 91675              1837.0         3.0             2760.0
# 91676              1345.0         8.0             1837.0
# 92568              2016.0         8.0             1918.0

# %%
#Serve stats by surface

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 5))

#Winner aces
plt.subplot(1, 2, 1)
sns.boxplot(x='Surface', y='Winner_Aces', data=df_best3, color='blue')  
plt.title('Winner Aces by Surface (Best of 3)')

#Winner double faults
plt.subplot(1, 2, 2)
sns.boxplot(x='Surface', y='Winner_DoubleFaults', data=df_best3, color='green')  # 
plt.title('Winner Double Faults by Surface (Best of 3)')

plt.tight_layout() 
plt.savefig('ServePerformance_By_Surface.png')
plt.show()

# %%
#Serve mean of aces and double fault barplot

#Aces
sns.barplot(x='Surface', y="Winner_Aces", data=df_best3, estimator='mean', errorbar=None)
plt.title('Winner Aces by surface (best of 3)')
plt.savefig('Bar graph Winner aces by surface')
plt.show()

#Double faults
sns.barplot(x='Surface', y="Winner_DoubleFaults", data=df_best3, estimator='mean', errorbar=None)
plt.title("Winner Double Faults by surface (best of 3)")
plt.savefig('Bar graph Winner Double Faults by surface')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
